# %%
#kleines Script um Massenweise Daten aus dem Shop zu löschen. Nur für Testzwecke um upload zu teste.
from woocommerce import API
import csv

# %%
#woocommerce API initialisieren
wcapi = API(
    url="http://192.168.179.18",
    consumer_key="ck_c6fd214c8762237fb583c6a1cc67d60028e93aac",
    consumer_secret="cs_b4562a3e66d67daa8a33e385ccf3cf4778ef3ac9",
    version="wc/v3"
)

# %%
#User Input für die Range der IDs welche gelöscht werden sollen
von=input("Start ID ")
bis=input("End ID ")
for i in range(int(von) , int(bis)):
    wcapi.delete("products/"+str(i)+"", params={"force": True}).json()
    print ("ID "+str(i)+" gelöscht")
# Out:
# Start ID 6065
# End ID 6841
# ID 6065 gelöscht
# ID 6066 gelöscht
# ID 6067 gelöscht
# ID 6068 gelöscht
# ID 6069 gelöscht
# ID 6070 gelöscht
# ID 6071 gelöscht
# ID 6072 gelöscht
# ID 6073 gelöscht
# ID 6074 gelöscht
# ID 6075 gelöscht
# ID 6076 gelöscht
# ID 6077 gelöscht
# ID 6078 gelöscht
# ID 6079 gelöscht
# ID 6080 gelöscht
# ID 6081 gelöscht
# ID 6082 gelöscht
# ID 6083 gelöscht
# ID 6084 gelöscht
# ID 6085 gelöscht
# ID 6086 gelöscht
# ID 6087 gelöscht
# ID 6088 gelöscht
# ID 6089 gelöscht
# ID 6090 gelöscht
# ID 6091 gelöscht
# ID 6092 gelöscht
# ID 6093 gelöscht
# ID 6094 gelöscht
# ID 6095 gelöscht
# ID 6096 gelöscht
# ID 6097 gelöscht
# ID 6098 gelöscht
# ID 6099 gelöscht
# ID 6100 gelöscht
# ID 6101 gelöscht
# ID 6102 gelöscht
# ID 6103 gelöscht
# ID 6104 gelöscht
# ID 6105 gelöscht
# ID 6106 gelöscht
# ID 6107 gelöscht
# ID 6108 gelöscht
# ID 6109 gelöscht
# ID 6110 gelöscht
# ID 6111 gelöscht
# ID 6112 gelöscht
# ID 6113 gelöscht
# ID 6114 gelöscht
# ID 6115 gelöscht
# ...
