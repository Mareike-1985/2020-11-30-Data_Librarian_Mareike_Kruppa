# %%
inputfile= open ('./tag_security.xml','r')
outputfile=open('./bibsonomy.xml','w')
outputfile.write("<Publikationen>\n")
outputfile.close()
outputfile=open('./bibsonomy.xml','a')

# %%
    for newline in inputfile:
        # newline = inputfile.readline()
        #print(newline)
        printer=0
        Titel=""
        Jahr=""
        Quelle=""
        Autoren=""
        Editoren=""
        ISBN=""
        Herausgeber=""
        if newline.find("<b:Year>") != -1:
            printer+=1
            Jahr = newline [newline.find("<b:Year>")+8:newline.rfind("</b:Year>")]
        if newline.find("<b:SourceType>") != -1:
            printer+=1
            Quelle = newline [newline.find("<b:SourceType>")+14:newline.rfind("</b:SourceType>")]
        if newline.find("<b:Title>") != -1:
            printer+=1
            Titel = newline [newline.find("<b:Title>")+9:newline.rfind("</b:Title>")]
        if newline.find("<b:Author>") != -1:
            Autoren = newline [newline.find("<b:Author>")+10:newline.rfind("</b:Author>")]
        if newline.find("<b:Editor>") != -1:
            Editoren = newline [newline.find("<b:Editor>")+10:newline.rfind("</b:Editor>")]
        if newline.find("<b:StandardNumber>") != -1:
            ISBN = newline [newline.find("<b:StandardNumber>")+18:newline.rfind("</b:StandardNumber>")]
        if newline.find("<b:Publisher>") != -1:
            Herausgeber = newline [newline.find("<b:Publisher>")+13:newline.rfind("</b:Publisher>")]
            
        #Formatierung von Autoren und Editoren    
        for person in range(1,Autoren.count("<b:Person>")): 
            if Autoren.find("<b:Middle>") != -1:
                Autor = Autoren [Autoren.find("<b:First>")+9:Autoren.find("</b:First>")]+" "+Autoren [Autoren.find("<b:Middle>")+10:Autoren.find("</b:Middle>")]+" "+Autoren [Autoren.find("<b:Last>")+8:Autoren.find("</b:Last>")]
            else:
                Autor += Autoren [Autoren.find("<b:First>")+9:Autoren.find("</b:First>")]+" "+Autoren [Autoren.find("<b:Last>")+8:Autoren.find("</b:Last>")]

            Autoren = Autoren [Autoren.find("</b:Person>")+11:-1]
            print (Autor)
        #if printer>=0:
            #outputfile.write("<Publikation><id>"+ISBN+"</id><Autor>"+Autoren+"</Autor><Editoren>"+Editoren+"</Editoren><Titel>"+Titel+"</Titel><Herausgeber>"+Herausgeber+"</Herausgeber><Jahr>"+Jahr+"</Jahr><Quelle>"+Quelle+"</quelle></Publikation>\n")
Jupyter Notebook
2_1_XML Last Checkpoint: letzten Montag um 21:47 Uhr (unsaved changes) Current Kernel Logo 

Python 3

    File
    Edit
    View
    Insert
    Cell
    Kernel
    Widgets
    Help

inputfile= open ('./tag_security.xml','r')

outputfile=open('./bibsonomy.xml','w')

outputfile.write("<Publikationen>\n")

outputfile.close()

outputfile=open('./bibsonomy.xml','a')

    for newline in inputfile:

        # newline = inputfile.readline()

        #print(newline)

        printer=0

        Titel=""

        Jahr=""

        Quelle=""

        Autoren=""

        Editoren=""

        ISBN=""

        Herausgeber=""

        if newline.find("<b:Year>") != -1:

            printer+=1

            Jahr = newline [newline.find("<b:Year>")+8:newline.rfind("</b:Year>")]

        if newline.find("<b:SourceType>") != -1:

            printer+=1

            Quelle = newline [newline.find("<b:SourceType>")+14:newline.rfind("</b:SourceType>")]

        if newline.find("<b:Title>") != -1:

            printer+=1

            Titel = newline [newline.find("<b:Title>")+9:newline.rfind("</b:Title>")]

        if newline.find("<b:Author>") != -1:

            Autoren = newline [newline.find("<b:Author>")+10:newline.rfind("</b:Author>")]

        if newline.find("<b:Editor>") != -1:

            Editoren = newline [newline.find("<b:Editor>")+10:newline.rfind("</b:Editor>")]

        if newline.find("<b:StandardNumber>") != -1:

            ISBN = newline [newline.find("<b:StandardNumber>")+18:newline.rfind("</b:StandardNumber>")]

        if newline.find("<b:Publisher>") != -1:

            Herausgeber = newline [newline.find("<b:Publisher>")+13:newline.rfind("</b:Publisher>")]

            

        #Formatierung von Autoren und Editoren    

        for person in range(1,Autoren.count("<b:Person>")): 

            if Autoren.find("<b:Middle>") != -1:

                Autor = Autoren [Autoren.find("<b:First>")+9:Autoren.find("</b:First>")]+" "+Autoren [Autoren.find("<b:Middle>")+10:Autoren.find("</b:Middle>")]+" "+Autoren [Autoren.find("<b:Last>")+8:Autoren.find("</b:Last>")]

            else:

                Autor += Autoren [Autoren.find("<b:First>")+9:Autoren.find("</b:First>")]+" "+Autoren [Autoren.find("<b:Last>")+8:Autoren.find("</b:Last>")]

​

            Autoren = Autoren [Autoren.find("</b:Person>")+11:-1]

            print (Autor)

        #if printer>=0:

            #outputfile.write("<Publikation><id>"+ISBN+"</id><Autor>"+Autoren+"</Autor><Editoren>"+Editoren+"</Editoren><Titel>"+Titel+"</Titel><Herausgeber>"+Herausgeber+"</Herausgeber><Jahr>"+Jahr+"</Jahr><Quelle>"+Quelle+"</quelle></Publikation>\n")

Alena A. Naiakshina
Anastasia A. Danilova
Eva A. Gerlitz
Emanuel A. von Zezschwitz
Matthew A. Smith
Stephen A. Brewster
Geraldine L. Fitzpatrick
Anna L. Cox
Vassilis Ellen Kostakos
Adam Ellen Shostack
Matthew Ellen Smith
Sam Ellen Weber
Matthew Duc Green
Matthew Duc Smith
Thomas Duc Prantl
Lukas Duc Iffländer
Stefan Duc Herrnleben
Simon Duc Engel
Samuel Duc Kounev
Christian Duc Krupitzer
Urvashi Duc Modi
Anurag Duc Jain
Michael Duc Brenner
Henning Duc Perl
Matthew Duc Smith
Alexandra Duc Dmitrienko
Stephan Duc Heuser
Thien Duc Nguyen
Marcos da Silva Ramos
Andre Rein
Marian Harbach
Sascha Fahl
Matthew Smith
M. Hettig
E. Kiss
J. f. Kassel
S. Weber
M. Harbach
Thomas Prantl
Lukas Iffländer
Stefan Herrnleben
Simon Engel
Samuel Kounev
Christian Krupitzer
Thomas Prantl
Peter Ten
Lukas Iffländer
Alexandra Dmitrenko
Samuel Kounev
Mousa Al-Akhras
Mohammed Alawairdhi
Ali Alkoudari
Samer Atawneh
Alena Naiakshina
Anastasia Danilova
Christian Tiefenau
Matthew Smith
Thomas Prantl
Peter Ten
Lukas Iffländer
Alexandra Dmitrenko
Samuel Kounev
Moritz Anton Finke
Katharina Eddine Krombholz
Karoline Eddine Busse
Katharina Eddine Pfeffer
Matthew Eddine Smith
Emanuel Eddine von Zezschwitz
Daniel Eddine Amo
Pablo Eddine G{\'{o}}mez
Luis Eddine Hern{\'{a}}ndez-Ib{\'{a}}{\~{n}}ez
David Eddine Fonseca
Ala Eddine Ben Yahya
Christoph Hagen
Christian Weinert
Christoph Sendner
Alexandra Dmitrienko
Alena 'Floyd' Naiakshina
Anastasia 'Floyd' Danilova
Eva 'Floyd' Gerlitz
Matthew 'Floyd' Smith
Regina 'Floyd' Bernhaupt
Florian 'Floyd' Mueller
David Paul Verweij
Josh Paul Andres
Joanna Paul McGrenere
Andy Paul Cockburn
Ignacio Paul Avellino
Alix Paul Goguey
# Out:
#   File "<ipython-input-29-4d6f102d616d>", line 41
#     Jupyter Notebook
#             ^
# SyntaxError: invalid syntax

# %%
outputfile.write("</Publikationen>")
outputfile.close()        
inputfile.close()
